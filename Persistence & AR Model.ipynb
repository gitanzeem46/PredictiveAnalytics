# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.ar_model import AutoReg

# %%
# Generate synthetic time series data (random walk)
np.random.seed(42)
n = 100
data = np.cumsum(np.random.randn(n))  # Cumulative sum to simulate trend

# Split data into train and test sets
train_size = int(len(data) * 0.8)     
train, test = data[:train_size], data[train_size:]   

# 1. Persistence Model (Naive Forecast)
def persistence_forecast(test, last_train_value):
    predictions = [last_train_value] * len(test)
    return predictions

# Persistence predictions (using last train value)
persistence_preds = persistence_forecast(test, train[-1])

# Calculate RMSE
persistence_rmse = np.sqrt(mean_squared_error(test, persistence_preds))

# 2. Autoregression Model (AR)
lag = 3  # Using 3 previous values
ar_model = AutoReg(train, lags=lag).fit()
ar_preds = ar_model.predict(start=len(train), end=len(data)-1)

# Calculate RMSE
ar_rmse = np.sqrt(mean_squared_error(test, ar_preds))

# Plot Results
plt.figure(figsize=(10, 5))
plt.plot(test, label="Actual Values", marker='o')
plt.plot(persistence_preds, label="Persistence Model", linestyle='dashed')
plt.plot(ar_preds, label="Autoregression Model", linestyle='dashed')
plt.legend()
plt.title("Comparison: Persistence vs. Autoregression")
plt.show()

# Print RMSE values
print(f"Persistence Model RMSE: {persistence_rmse:.3f}")
print(f"Autoregression Model RMSE: {ar_rmse:.3f}")
# Out:
# Persistence Model RMSE: 0.925
# Autoregression Model RMSE: 1.036

# %% [markdown]
# ### ACF & PCAF

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Generate synthetic time series data (random walk)
np.random.seed(42)
n = 100
data = np.cumsum(np.random.randn(n))  # Cumulative sum to simulate trend

# Plot time series data
plt.figure(figsize=(10, 4))
plt.plot(data)
plt.title("Time Series Data")
plt.show()

# Plot ACF & PACF 
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# ACF Plot
plot_acf(data, lags=20, ax=axes[0])
axes[0].set_title("Autocorrelation Function (ACF)")

# PACF Plot
plot_pacf(data, lags=20, ax=axes[1])
axes[1].set_title("Partial Autocorrelation Function (PACF)")

plt.tight_layout()
plt.show()

# %%
### Make Predictiond on Test Set and compare

# %%
pred = model_fit.predict(start=len(train),end=len(train)

# %%
### Calculate Error

# %%
test.shape

# %%
pred.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pred.shape
#
# NameError: name 'pred' is not defined

# %%
from sklearn.metrics import mean_sqaured_error

rmse=np.sqrt(mean_squared_error(test,pred))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.metrics import mean_sqaured_error
#
# ImportError: cannot import name 'mean_sqaured_error' from 'sklearn.metrics' (/opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/__init__.py)

# %%
## Making Future Predictions

# %%
pred_future = model_fit.predict(start=len(x), end=len(x)+5, dynamic=False)

print("The future prediction for the next week")
print(pred_future)
print("Number of predictions Made:" len(pred_future))
# Out:
#   Cell In[14], line 5
#     print("Number of predictions Made:" len(pred_future))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
The
